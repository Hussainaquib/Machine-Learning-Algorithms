# %% [markdown]
# # ElasticNet Regression
# - ElasticNet is combination of Ridge Regression and Lasso Regression.
# - ElasticNet Regression use when we can't predict which we use lasso or ridge.

# %% [markdown]
# ![IMG_20240304_111249_414.jpg](attachment:IMG_20240304_111249_414.jpg)

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# ### R2 score calculation using Linear Regression

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %% [markdown]
# ### R2 score calculation using Ridge Regression

# %%
reg = Ridge(alpha=0.1)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.45199494197195467

# %% [markdown]
# ### R2 score calculation using Lasso Regression

# %%
reg = Lasso(alpha=0.01)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.44111855963110613

# %% [markdown]
# ### R2 score calculation using ElasticNet Regression

# %%
reg = ElasticNet(alpha=0.005,l1_ratio=0.9)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4531474541554823
